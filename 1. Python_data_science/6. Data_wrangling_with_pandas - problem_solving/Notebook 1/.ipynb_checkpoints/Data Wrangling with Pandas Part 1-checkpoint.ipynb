# %% [markdown]
# # IPL Dataset Analysis
#
# ## Problem Statement
# We want to know as to what happens during an IPL match which raises several questions in our mind with our limited knowledge about the game called cricket on which it is based. This analysis is done to know as which factors led one of the team to win and how does it matter.

# %% [markdown]
# ## About the Dataset :
# The Indian Premier League (IPL) is a professional T20 cricket league in India contested during April-May of every year by teams representing Indian cities. It is the most-attended cricket league in the world and ranks sixth among all the sports leagues. It has teams with players from around the world and is very competitive and entertaining with a lot of close matches between teams.
#
# The IPL and other cricket related datasets are available at [cricsheet.org](https://cricsheet.org/%c2%a0(data). Feel free to visit the website and explore the data by yourself as exploring new sources of data is one of the interesting activities a data scientist gets to do.
#
# Snapshot of the data you will be working on:<br>
# <br>
# The dataset 136522 data points and 23 features<br>
#
# |Features|Description|
# |-----|-----|
# |match_code|Code pertaining to individual match|
# |date|Date of the match played|
# |city|City where the match was played|
# |venue|Stadium in that city where the match was played|
# |team1|team1|
# |team2|team2|
# |toss_winner|Who won the toss out of two teams|
# |toss_decision|toss decision taken by toss winner|
# |winner|Winner of that match between two teams|
# |win_type|How did the team won(by wickets or runs etc.)|
# |win_margin|difference with which the team won|
# |inning|inning type(1st or 2nd)|
# |delivery|ball delivery|
# |batting_team|current team on batting|
# |batsman|current batsman on strike|
# |non_striker|batsman on non-strike|
# |bowler|Current bowler|
# |runs|runs scored|
# |extras|extra run scored|
# |total|total run scored on that delivery including runs and extras|
# |extras_type|extra run scored by wides or no ball or legby|
# |player_out|player that got out|
# |wicket_kind|How did the player got out|
# |wicket_fielders|Fielder who caught out the player by catch|

# %% [markdown]
# ### Analyzing data using pandas module

# %% [markdown]
# ### Read the data using pandas module.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('./data/ipl_dataset.csv')
df.shape
df
# Out:
#         match_code        date         city             venue  \
# 0           392203  2009-05-01  East London      Buffalo Park
# 1           392203  2009-05-01  East London      Buffalo Park
# 2           392203  2009-05-01  East London      Buffalo Park
# 3           392203  2009-05-01  East London      Buffalo Park
# 4           392203  2009-05-01  East London      Buffalo Park
# 5           392203  2009-05-01  East London      Buffalo Park
# 6           392203  2009-05-01  East London      Buffalo Park
# 7           392203  2009-05-01  East London      Buffalo Park
# 8           392203  2009-05-01  East London      Buffalo Park
# 9           392203  2009-05-01  East London      Buffalo Park
# 10          392203  2009-05-01  East London      Buffalo Park
# 11          392203  2009-05-01  East London      Buffalo Park
# 12          392203  2009-05-01  East London      Buffalo Park
# 13          392203  2009-05-01  East London      Buffalo Park
# 14          392203  2009-05-01  East London      Buffalo Park
# 15          392203  2009-05-01  East London      Buffalo Park
# 16          392203  2009-05-01  East London      Buffalo Park
# 17          392203  2009-05-01  East London      Buffalo Park
# 18          392203  2009-05-01  East London      Buffalo Park
# 19          392203  2009-05-01  East London      Buffalo Park
# 20          392203  2009-05-01  East London      Buffalo Park
# 21          392203  2009-05-01  East London      Buffalo Park
# 22          392203  2009-05-01  East London      Buffalo Park
# 23          392203  2009-05-01  East London      Buffalo Park
# 24          392203  2009-05-01  East London      Buffalo Park
# 25          392203  2009-05-01  East London      Buffalo Park
# 26          392203  2009-05-01  East London      Buffalo Park
# 27          392203  2009-05-01  East London      Buffalo Park
# 28          392203  2009-05-01  East London      Buffalo Park
# 29          392203  2009-05-01  East London      Buffalo Park
# ...            ...         ...          ...               ...
# 136492      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136493      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136494      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136495      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136496      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136497      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136498      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136499      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136500      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136501      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136502      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136503      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136504      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136505      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136506      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136507      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136508      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136509      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136510      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136511      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136512      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136513      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136514      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136515      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136516      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136517      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136518      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136519      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136520      336018  2008-05-14       Mumbai  Wankhede Stadium
# 136521      336018  2008-05-14       Mumbai  Wankhede Stadium
#
#                         team1                team2     toss_winner  \
# 0       Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 1       Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 2       Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 3       Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 4       Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 5       Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 6       Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 7       Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 8       Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 9       Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 10      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 11      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 12      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 13      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 14      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 15      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 16      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 17      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 18      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 19      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 20      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 21      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 22      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 23      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 24      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 25      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 26      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 27      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 28      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# 29      Kolkata Knight Riders       Mumbai Indians  Mumbai Indians
# ...                       ...                  ...             ...
# 136492         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136493         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136494         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136495         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136496         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136497         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136498         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136499         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136500         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136501         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136502         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136503         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136504         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136505         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136506         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136507         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136508         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136509         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136510         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136511         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136512         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136513         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136514         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136515         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136516         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136517         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136518         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136519         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136520         Mumbai Indians  Chennai Super Kings  Mumbai Indians
# 136521         Mumbai Indians  Chennai Super Kings  Mumbai Indians
#
#        toss_decision          winner win_type       ...         \
# 0                bat  Mumbai Indians     runs       ...
# 1                bat  Mumbai Indians     runs       ...
# 2                bat  Mumbai Indians     runs       ...
# 3                bat  Mumbai Indians     runs       ...
# 4                bat  Mumbai Indians     runs       ...
# 5                bat  Mumbai Indians     runs       ...
# 6                bat  Mumbai Indians     runs       ...
# 7                bat  Mumbai Indians     runs       ...
# 8                bat  Mumbai Indians     runs       ...
# 9                bat  Mumbai Indians     runs       ...
# 10               bat  Mumbai Indians     runs       ...
# 11               bat  Mumbai Indians     runs       ...
# 12               bat  Mumbai Indians     runs       ...
# 13               bat  Mumbai Indians     runs       ...
# 14               bat  Mumbai Indians     runs       ...
# 15               bat  Mumbai Indians     runs       ...
# 16               bat  Mumbai Indians     runs       ...
# 17               bat  Mumbai Indians     runs       ...
# 18               bat  Mumbai Indians     runs       ...
# 19               bat  Mumbai Indians     runs       ...
# 20               bat  Mumbai Indians     runs       ...
# 21               bat  Mumbai Indians     runs       ...
# 22               bat  Mumbai Indians     runs       ...
# 23               bat  Mumbai Indians     runs       ...
# 24               bat  Mumbai Indians     runs       ...
# 25               bat  Mumbai Indians     runs       ...
# 26               bat  Mumbai Indians     runs       ...
# 27               bat  Mumbai Indians     runs       ...
# 28               bat  Mumbai Indians     runs       ...
# 29               bat  Mumbai Indians     runs       ...
# ...              ...             ...      ...       ...
# 136492         field  Mumbai Indians  wickets       ...
# 136493         field  Mumbai Indians  wickets       ...
# 136494         field  Mumbai Indians  wickets       ...
# 136495         field  Mumbai Indians  wickets       ...
# 136496         field  Mumbai Indians  wickets       ...
# 136497         field  Mumbai Indians  wickets       ...
# 136498         field  Mumbai Indians  wickets       ...
# 136499         field  Mumbai Indians  wickets       ...
# 136500         field  Mumbai Indians  wickets       ...
# 136501         field  Mumbai Indians  wickets       ...
# 136502         field  Mumbai Indians  wickets       ...
# 136503         field  Mumbai Indians  wickets       ...
# 136504         field  Mumbai Indians  wickets       ...
# 136505         field  Mumbai Indians  wickets       ...
# 136506         field  Mumbai Indians  wickets       ...
# 136507         field  Mumbai Indians  wickets       ...
# 136508         field  Mumbai Indians  wickets       ...
# 136509         field  Mumbai Indians  wickets       ...
# 136510         field  Mumbai Indians  wickets       ...
# 136511         field  Mumbai Indians  wickets       ...
# 136512         field  Mumbai Indians  wickets       ...
# 136513         field  Mumbai Indians  wickets       ...
# 136514         field  Mumbai Indians  wickets       ...
# 136515         field  Mumbai Indians  wickets       ...
# 136516         field  Mumbai Indians  wickets       ...
# 136517         field  Mumbai Indians  wickets       ...
# 136518         field  Mumbai Indians  wickets       ...
# 136519         field  Mumbai Indians  wickets       ...
# 136520         field  Mumbai Indians  wickets       ...
# 136521         field  Mumbai Indians  wickets       ...
#
#                 batsman      non_striker           bowler runs extras total  \
# 0         ST Jayasuriya     SR Tendulkar         I Sharma    0      1     1
# 1         ST Jayasuriya     SR Tendulkar         I Sharma    1      0     1
# 2          SR Tendulkar    ST Jayasuriya         I Sharma    0      1     1
# 3          SR Tendulkar    ST Jayasuriya         I Sharma    0      0     0
# 4          SR Tendulkar    ST Jayasuriya         I Sharma    2      0     2
# 5          SR Tendulkar    ST Jayasuriya         I Sharma    0      0     0
# 6          SR Tendulkar    ST Jayasuriya         I Sharma    0      0     0
# 7          SR Tendulkar    ST Jayasuriya         I Sharma    4      0     4
# 8         ST Jayasuriya     SR Tendulkar         AB Dinda    4      0     4
# 9         ST Jayasuriya     SR Tendulkar         AB Dinda    0      0     0
# 10        ST Jayasuriya     SR Tendulkar         AB Dinda    1      0     1
# 11         SR Tendulkar    ST Jayasuriya         AB Dinda    0      0     0
# 12         SR Tendulkar    ST Jayasuriya         AB Dinda    0      0     0
# 13         SR Tendulkar    ST Jayasuriya         AB Dinda    1      0     1
# 14         SR Tendulkar    ST Jayasuriya         I Sharma    0      0     0
# 15         SR Tendulkar    ST Jayasuriya         I Sharma    0      0     0
# 16         SR Tendulkar    ST Jayasuriya         I Sharma    1      0     1
# 17        ST Jayasuriya     SR Tendulkar         I Sharma    0      2     2
# 18        ST Jayasuriya     SR Tendulkar         I Sharma    0      0     0
# 19        ST Jayasuriya     SR Tendulkar         I Sharma    0      0     0
# 20         SR Tendulkar    ST Jayasuriya         AB Dinda    0      1     1
# 21        ST Jayasuriya     SR Tendulkar         AB Dinda    0      0     0
# 22      Harbhajan Singh     SR Tendulkar         AB Dinda    0      1     1
# 23      Harbhajan Singh     SR Tendulkar         AB Dinda    0      0     0
# 24      Harbhajan Singh     SR Tendulkar         AB Dinda    2      0     2
# 25      Harbhajan Singh     SR Tendulkar         AB Dinda    1      0     1
# 26         SR Tendulkar  Harbhajan Singh         AB Dinda    1      0     1
# 27         SR Tendulkar  Harbhajan Singh        LR Shukla    0      0     0
# 28         SR Tendulkar  Harbhajan Singh        LR Shukla    1      0     1
# 29      Harbhajan Singh     SR Tendulkar        LR Shukla    1      0     1
# ...                 ...              ...              ...  ...    ...   ...
# 136492       RV Uthappa    ST Jayasuriya  Joginder Sharma    4      0     4
# 136493       RV Uthappa    ST Jayasuriya  Joginder Sharma    0      0     0
# 136494       RV Uthappa    ST Jayasuriya  Joginder Sharma    0      2     2
# 136495    ST Jayasuriya       RV Uthappa  Joginder Sharma    4      0     4
# 136496    ST Jayasuriya       RV Uthappa  Joginder Sharma    6      0     6
# 136497    ST Jayasuriya       RV Uthappa  Joginder Sharma    0      0     0
# 136498       RV Uthappa    ST Jayasuriya   M Muralitharan    0      1     1
# 136499       RV Uthappa    ST Jayasuriya   M Muralitharan    0      0     0
# 136500       RV Uthappa    ST Jayasuriya   M Muralitharan    1      0     1
# 136501    ST Jayasuriya       RV Uthappa   M Muralitharan    0      0     0
# 136502    ST Jayasuriya       RV Uthappa   M Muralitharan    4      0     4
# 136503    ST Jayasuriya       RV Uthappa   M Muralitharan    0      0     0
# 136504    ST Jayasuriya       RV Uthappa   M Muralitharan    2      0     2
# 136505       RV Uthappa    ST Jayasuriya  Joginder Sharma    1      0     1
# 136506    ST Jayasuriya       RV Uthappa  Joginder Sharma    1      0     1
# 136507       RV Uthappa    ST Jayasuriya  Joginder Sharma    0      0     0
# 136508       RV Uthappa    ST Jayasuriya  Joginder Sharma    1      0     1
# 136509    ST Jayasuriya       RV Uthappa  Joginder Sharma    1      0     1
# 136510       RV Uthappa    ST Jayasuriya  Joginder Sharma    1      0     1
# 136511       RV Uthappa    ST Jayasuriya   M Muralitharan    4      0     4
# 136512       RV Uthappa    ST Jayasuriya   M Muralitharan    1      0     1
# 136513    ST Jayasuriya       RV Uthappa   M Muralitharan    1      0     1
# 136514       RV Uthappa    ST Jayasuriya   M Muralitharan    1      0     1
# 136515    ST Jayasuriya       RV Uthappa   M Muralitharan    4      0     4
# 136516    ST Jayasuriya       RV Uthappa   M Muralitharan    1      0     1
# 136517    ST Jayasuriya       RV Uthappa    CK Kapugedera    6      0     6
# 136518    ST Jayasuriya       RV Uthappa    CK Kapugedera    6      0     6
# 136519    ST Jayasuriya       RV Uthappa    CK Kapugedera    6      0     6
# 136520    ST Jayasuriya       RV Uthappa    CK Kapugedera    4      0     4
# 136521    ST Jayasuriya       RV Uthappa    CK Kapugedera    4      0     4
#
#        extras_type     player_out  wicket_kind  wicket_fielders
# 0            wides            NaN          NaN              NaN
# 1              NaN            NaN          NaN              NaN
# 2            wides            NaN          NaN              NaN
# 3              NaN            NaN          NaN              NaN
# 4              NaN            NaN          NaN              NaN
# 5              NaN            NaN          NaN              NaN
# 6              NaN            NaN          NaN              NaN
# 7              NaN            NaN          NaN              NaN
# 8              NaN            NaN          NaN              NaN
# 9              NaN            NaN          NaN              NaN
# 10             NaN            NaN          NaN              NaN
# 11             NaN            NaN          NaN              NaN
# 12             NaN            NaN          NaN              NaN
# 13             NaN            NaN          NaN              NaN
# 14             NaN            NaN          NaN              NaN
# 15             NaN            NaN          NaN              NaN
# 16             NaN            NaN          NaN              NaN
# 17            byes            NaN          NaN              NaN
# 18             NaN            NaN          NaN              NaN
# 19             NaN            NaN          NaN              NaN
# 20         legbyes            NaN          NaN              NaN
# 21             NaN  ST Jayasuriya       caught       MN van Wyk
# 22           wides            NaN          NaN              NaN
# 23             NaN            NaN          NaN              NaN
# 24             NaN            NaN          NaN              NaN
# 25             NaN            NaN          NaN              NaN
# 26             NaN            NaN          NaN              NaN
# 27             NaN            NaN          NaN              NaN
# 28             NaN            NaN          NaN              NaN
# 29             NaN            NaN          NaN              NaN
# ...            ...            ...          ...              ...
# 136492         NaN            NaN          NaN              NaN
# 136493         NaN            NaN          NaN              NaN
# 136494       wides            NaN          NaN              NaN
# 136495         NaN            NaN          NaN              NaN
# 136496         NaN            NaN          NaN              NaN
# 136497         NaN            NaN          NaN              NaN
# 136498       wides            NaN          NaN              NaN
# 136499         NaN            NaN          NaN              NaN
# 136500         NaN            NaN          NaN              NaN
# 136501         NaN            NaN          NaN              NaN
# 136502         NaN            NaN          NaN              NaN
# 136503         NaN            NaN          NaN              NaN
# 136504         NaN            NaN          NaN              NaN
# 136505         NaN            NaN          NaN              NaN
# 136506         NaN            NaN          NaN              NaN
# 136507         NaN            NaN          NaN              NaN
# 136508         NaN            NaN          NaN              NaN
# 136509         NaN            NaN          NaN              NaN
# 136510         NaN            NaN          NaN              NaN
# 136511         NaN            NaN          NaN              NaN
# 136512         NaN            NaN          NaN              NaN
# 136513         NaN            NaN          NaN              NaN
# 136514         NaN            NaN          NaN              NaN
# 136515         NaN            NaN          NaN              NaN
# 136516         NaN            NaN          NaN              NaN
# 136517         NaN            NaN          NaN              NaN
# 136518         NaN            NaN          NaN              NaN
# 136519         NaN            NaN          NaN              NaN
# 136520         NaN            NaN          NaN              NaN
# 136521         NaN            NaN          NaN              NaN
#
# [136522 rows x 24 columns]

# %%
len(df['match_code'].unique())

# You can also use: 
#df_ipl['match_code'].nunique()
# Out:
# 577

# %% [markdown]
# ### There are certain fixed cities all around the world where matches are held. Find the list of unique cities where matches were played

# %%
# Corrected as Venues to Cities
i = df['city'].unique()
for a in i:
    print(a)
len(i)
# Out:
# East London
# Port Elizabeth
# Centurion
# neutral_venue
# Chennai
# Jaipur
# Kolkata
# Delhi
# Chandigarh
# Hyderabad
# Ranchi
# Mumbai
# Bangalore
# Dharamsala
# Pune
# Rajkot
# Durban
# Cuttack
# Cape Town
# Ahmedabad
# Johannesburg
# Visakhapatnam
# Abu Dhabi
# Raipur
# Kochi
# Kimberley
# Nagpur
# Bloemfontein
# Indore
# Kanpur
# 30

# %% [markdown]
# ### Find the columns which contains null values if any ?

# %%
df.isna().any()
# Out:
# match_code         False
# date               False
# city               False
# venue              False
# team1              False
# team2              False
# toss_winner        False
# toss_decision      False
# winner              True
# win_type            True
# win_margin          True
# inning             False
# delivery           False
# batting_team       False
# batsman            False
# non_striker        False
# bowler             False
# runs               False
# extras             False
# total              False
# extras_type         True
# player_out          True
# wicket_kind         True
# wicket_fielders     True
# dtype: bool

# %%
df.isna().sum()
# Out:
# match_code              0
# date                    0
# city                    0
# venue                   0
# team1                   0
# team2                   0
# toss_winner             0
# toss_decision           0
# winner               1818
# win_type             1818
# win_margin           1818
# inning                  0
# delivery                0
# batting_team            0
# batsman                 0
# non_striker             0
# bowler                  0
# runs                    0
# extras                  0
# total                   0
# extras_type        129064
# player_out         129807
# wicket_kind        129807
# wicket_fielders    131657
# dtype: int64

# %% [markdown]
# ### Though the match is held in different cities all around the world it may or maynot have multiple venues (stadiums where matches are held) list down top 5 most played venues

# %%
venue = df.groupby(['venue'])['match_code'].nunique().sort_values(ascending = False).head(5)
venue
# Out:
# venue
# M Chinnaswamy Stadium              58
# Eden Gardens                       54
# Feroz Shah Kotla                   53
# Wankhede Stadium                   49
# MA Chidambaram Stadium, Chepauk    48
# Name: match_code, dtype: int64

# %% [markdown]
# ### Make a runs vs run-count frequency table

# %%
df['runs'].value_counts()
# Out:
# 0    55870
# 1    50087
# 4    15409
# 2     8835
# 6     5806
# 3      473
# 5       42
# Name: runs, dtype: int64

# %% [markdown]
# ### IPL seasons are held every year now let's look at our data and extract how many seasons were recorded.

# %%
df['years'] = pd.DatetimeIndex(df['date']).year
a = df['years'].value_counts()
print('The number of seasons that were held is', a.count())
# Out:
# The number of seasons that were held is 9

# %% [markdown]
# ### What are the total no. of matches played per season

# %%
df.groupby(['years'])['match_code'].nunique()
# Out:
# years
# 2008    58
# 2009    57
# 2010    60
# 2011    73
# 2012    74
# 2013    76
# 2014    60
# 2015    59
# 2016    60
# Name: match_code, dtype: int64

# %% [markdown]
# ### What are the total runs scored across each season

# %%
df.groupby(['years','inning'])['runs'].sum().sort_values(ascending = False)
#for each year(seasons) , innings ,which team scored the maximum no of runs in that year and inning
# Out:
# years  inning
# 2013   1         11286
# 2012   1         11054
# 2011   1         10474
# 2012   2         10268
# 2013   2         10141
# 2011   2          9454
# 2016   1          9342
# 2015   1          9291
# 2010   1          9279
# 2014   1          9239
# 2008   1          8788
# 2014   2          8683
# 2016   2          8621
# 2010   2          8455
# 2015   2          8118
# 2009   1          8088
# 2008   2          8021
# 2009   2          7256
# Name: runs, dtype: int64

# %%
a = df['total'].sum()
df.groupby(['years','inning','batting_team'])['total'].apply(lambda grp : grp.sum())
#Total runs scored by each team as per the years and that year's winnings
# Out:
# years  inning  batting_team
# 2008   1       Chennai Super Kings            1548
#                Deccan Chargers                1257
#                Delhi Daredevils               1004
#                Kings XI Punjab                1222
#                Kolkata Knight Riders          1335
#                Mumbai Indians                  979
#                Rajasthan Royals               1028
#                Royal Challengers Bangalore     962
#        2       Chennai Super Kings             972
#                Deccan Chargers                 972
#                Delhi Daredevils               1114
#                Kings XI Punjab                1242
#                Kolkata Knight Riders           607
#                Mumbai Indians                 1100
#                Rajasthan Royals               1573
#                Royal Challengers Bangalore    1021
# 2009   1       Chennai Super Kings            1613
#                Deccan Chargers                1263
#                Delhi Daredevils               1062
#                Kings XI Punjab                 773
#                Kolkata Knight Riders          1003
#                Mumbai Indians                 1234
#                Rajasthan Royals                747
#                Royal Challengers Bangalore     870
#        2       Chennai Super Kings             618
#                Deccan Chargers                1145
#                Delhi Daredevils               1069
#                Kings XI Punjab                1155
#                Kolkata Knight Riders           754
#                Mumbai Indians                  663
#                                               ...
# 2015   1       Kings XI Punjab                1034
#                Kolkata Knight Riders           626
#                Mumbai Indians                 1800
#                Rajasthan Royals                871
#                Royal Challengers Bangalore    1146
#                Sunrisers Hyderabad            1442
#        2       Chennai Super Kings             956
#                Delhi Daredevils               1047
#                Kings XI Punjab                 969
#                Kolkata Knight Riders          1418
#                Mumbai Indians                  934
#                Rajasthan Royals               1266
#                Royal Challengers Bangalore    1164
#                Sunrisers Hyderabad             768
# 2016   1       Delhi Daredevils                869
#                Gujarat Lions                   902
#                Kings XI Punjab                1239
#                Kolkata Knight Riders          1161
#                Mumbai Indians                 1097
#                Rising Pune Supergiants        1123
#                Royal Challengers Bangalore    1923
#                Sunrisers Hyderabad            1442
#        2       Delhi Daredevils               1235
#                Gujarat Lions                  1548
#                Kings XI Punjab                 895
#                Kolkata Knight Riders          1102
#                Mumbai Indians                 1097
#                Rising Pune Supergiants         940
#                Royal Challengers Bangalore    1058
#                Sunrisers Hyderabad            1231
# Name: total, Length: 152, dtype: int64

# %%
# pd.set_option('expand_frame_repr', True)
pd.set_option("display.max_rows", 999)
pd.set_option('max_colwidth',100)

# %% [markdown]
# ### There are teams which are high performing and low performing. Let's look at the aspect of performance of an individual team. Filter the data and aggregate the runs scored by each team. Display top 10 results which are having runs scored over 200.

# %%
df.groupby(['match_code','batting_team','inning'])['total'].sum().sort_values(ascending = False).head(10)
# Out:
# match_code  batting_team                 inning
# 598027      Royal Challengers Bangalore  1         263
# 980987      Royal Challengers Bangalore  1         248
# 419137      Chennai Super Kings          1         246
# 335983      Chennai Super Kings          1         240
# 829795      Royal Challengers Bangalore  1         235
# 501260      Kings XI Punjab              1         232
# 733987      Kings XI Punjab              1         231
# 501223      Delhi Daredevils             1         231
# 980907      Royal Challengers Bangalore  1         227
# 829785      Royal Challengers Bangalore  1         226
# Name: total, dtype: int64

# %% [markdown]
# ### Chasing a 200+ target is difficulty in T-20 format. What are the chances that a team scoring runs above 200  in their 1st inning is chased by the opposition in 2nd inning.

# %%
f = pd.DataFrame(df[df['inning'] == 1].groupby('match_code')['total'].sum())
s = pd.DataFrame(df[df['inning'] == 2].groupby('match_code')['total'].sum())
f.head(5)
# Out:
#             total
# match_code
# 335982        222
# 335983        240
# 335984        129
# 335985        165
# 335986        110

# %%
df_joined = f.join(s, lsuffix='_first', rsuffix='_second')
df_joined.head(4)
# Out:
#             total_first  total_second
# match_code
# 335982              222          82.0
# 335983              240         207.0
# 335984              129         132.0
# 335985              165         166.0

# %%
df_joined = df_joined[(df_joined['total_first'] > 200) & (df_joined['total_second'] > df_joined['total_first'])]
df_joined
# Out:
#             total_first  total_second
# match_code
# 335990              214         217.0
# 419112              203         204.0
# 548318              205         208.0
# 729283              205         206.0
# 734007              205         211.0

# %%
teams_chased = df_joined['total_first'].count()
print(teams_chased)
total_matches = f[f['total'] > 200]['total'].count()
print(total_matches)
probability = teams_chased/total_matches
print(probability)
# Out:
# 5
# 39
# 0.1282051282051282

# %% [markdown]
# ### Every season has that one team which is outperforming others and is in great form. Which team has the highest win counts in their respective seasons ?

# %%
print(pd.DataFrame(df.groupby(['years','batting_team'])['winner'].nunique()).sort_values(by = 'winner', ascending = False))
print("As per the data above, the team that is outperforming other teams is Delhi Daredevils")
# Out:
#                                    winner
# years batting_team
# 2013  Delhi Daredevils                  9
#       Pune Warriors                     9
#       Kolkata Knight Riders             9
# 2011  Delhi Daredevils                  9
# 2012  Pune Warriors                     9
# 2010  Kings XI Punjab                   8
# 2015  Kings XI Punjab                   8
# 2011  Kochi Tuskers Kerala              8
# 2014  Delhi Daredevils                  8
# 2011  Pune Warriors                     8
# 2012  Deccan Chargers                   8
# 2016  Kings XI Punjab                   8
# 2008  Deccan Chargers                   8
# 2011  Deccan Chargers                   8
# 2014  Royal Challengers Bangalore       7
# 2013  Mumbai Indians                    7
#       Rajasthan Royals                  7
# 2012  Kings XI Punjab                   7
#       Mumbai Indians                    7
# 2011  Kings XI Punjab                   7
# 2012  Rajasthan Royals                  7
#       Royal Challengers Bangalore       7
# 2014  Sunrisers Hyderabad               7
# 2015  Mumbai Indians                    7
# 2008  Royal Challengers Bangalore       7
# 2010  Kolkata Knight Riders             7
# 2015  Delhi Daredevils                  7
# 2016  Rising Pune Supergiants           7
# 2009  Royal Challengers Bangalore       7
#       Rajasthan Royals                  7
# 2008  Mumbai Indians                    7
# 2009  Mumbai Indians                    7
#       Kings XI Punjab                   7
# 2015  Sunrisers Hyderabad               7
# 2016  Delhi Daredevils                  7
#       Royal Challengers Bangalore       6
#       Mumbai Indians                    6
#       Kolkata Knight Riders             6
# 2013  Kings XI Punjab                   6
# 2014  Mumbai Indians                    6
# 2013  Royal Challengers Bangalore       6
#       Sunrisers Hyderabad               6
# 2015  Kolkata Knight Riders             6
#       Chennai Super Kings               6
# 2008  Chennai Super Kings               6
# 2012  Kolkata Knight Riders             6
# 2010  Delhi Daredevils                  6
# 2009  Kolkata Knight Riders             6
# 2010  Deccan Chargers                   6
#       Rajasthan Royals                  6
#       Royal Challengers Bangalore       6
# 2009  Delhi Daredevils                  6
# 2011  Chennai Super Kings               6
# 2009  Deccan Chargers                   6
#       Chennai Super Kings               6
# 2011  Mumbai Indians                    6
#       Rajasthan Royals                  6
# 2008  Delhi Daredevils                  6
# 2012  Chennai Super Kings               6
# 2010  Chennai Super Kings               6
# 2016  Gujarat Lions                     5
# 2008  Kolkata Knight Riders             5
# 2015  Royal Challengers Bangalore       5
#       Rajasthan Royals                  5
# 2013  Chennai Super Kings               5
# 2012  Delhi Daredevils                  5
# 2010  Mumbai Indians                    5
# 2014  Rajasthan Royals                  5
#       Kolkata Knight Riders             5
# 2011  Kolkata Knight Riders             5
# 2014  Chennai Super Kings               5
# 2011  Royal Challengers Bangalore       5
# 2016  Sunrisers Hyderabad               5
# 2008  Rajasthan Royals                  4
#       Kings XI Punjab                   4
# 2014  Kings XI Punjab                   3
# As per the data above, the team that is outperforming other teams is Delhi Daredevils
